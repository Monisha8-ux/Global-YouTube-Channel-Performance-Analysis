# %% [markdown]
# #Title: YouTube Channel Performance and Global Trends Analysis

# %% [markdown]
# ##Problem Statement

# %% [markdown]
# The objective of this project is to analyze global YouTube channel statistics to identify patterns in subscriber growth, content categories, country distribution, and channel performance. The analysis will help understand which factors contribute to high subscriber counts and video views.

# %% [markdown]
# #Phase 1 — Data Loading and Inspection

# %%
#Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("youtube.csv", encoding='latin1')
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %%
df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %% [markdown]
# ##Understanding of dataset

# %%
df.shape
# Out:
# (995, 28)

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
df.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# ...

# %% [markdown]
# #Phase 2 — Data Cleaning

# %%
#Check the missing values
df.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)

# %%
df.dtypes
# Out:
# rank                                         int64
# Youtuber                                    object
# subscribers                                  int64
# video views                                float64
# category                                    object
# Title                                       object
# uploads                                      int64
# Country                                     object
# Abbreviation                                object
# channel_type                                object
# video_views_rank                           float64
# country_rank                               float64
# channel_type_rank                          float64
# video_views_for_the_last_30_days           float64
# lowest_monthly_earnings                    float64
# highest_monthly_earnings                   float64
# lowest_yearly_earnings                     float64
# highest_yearly_earnings                    float64
# ...

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ##Phase 3 — Exploratory Data Analysis (EDA)

# %% [markdown]
# ##Bivariate Analysis

# %%
#Top categories of subscribers
category_sub = df.groupby("category")["subscribers"].sum().sort_values(ascending=False)
category_sub.head(10)
# Out:
# category
# Music               5195000000
# Entertainment       5158200000
# People & Blogs      2779400000
# Gaming              1960100000
# Comedy              1388500000
# Film & Animation    1314900000
# Education           1194400000
# Howto & Style        775600000
# Shows                541000000
# News & Politics      536400000
# Name: subscribers, dtype: int64

# %% [markdown]
# ##Univariate Analysis

# %%
#Top countries contributing to the youtube viewership
df["Country"].value_counts().head(10)
# Out:
# Country
# United States     313
# India             168
# Brazil             62
# United Kingdom     43
# Mexico             33
# Indonesia          28
# Spain              22
# Thailand           18
# South Korea        17
# Russia             16
# Name: count, dtype: int64

# %%
#Most Viewed Channels
df.sort_values("video views", ascending=False).head(10)
# Out:
#     rank                    Youtuber  subscribers   video views  \
# 0      1                    T-Series    245000000  2.280000e+11
# 3      4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4      5                   SET India    159000000  1.480000e+11
# 15    16                    Sony SAB     83000000  1.010000e+11
# 6      7         ýýý Kids Diana Show    112000000  9.324704e+10
# 8      9                 Like Nastya    106000000  9.047906e+10
# 11    12                         WWE     96000000  7.742847e+10
# 9     10               Vlad and Niki     98900000  7.718017e+10
# 21    22                      Zee TV     70500000  7.313905e+10
# 26    27                   Colors TV     64600000  6.151091e+10
#
#           category                       Title  uploads        Country  \
# 0            Music                    T-Series    20082          India
# 3        Education  Cocomelon - Nursery Rhymes      966  United States
# ...

# %%
avg_views = df.groupby("category")["video views"].mean().round(3)
avg_views
# Out:
# category
# Autos & Vehicles         7.501729e+09
# Comedy                   7.972649e+09
# Education                1.548032e+10
# Entertainment            1.048854e+10
# Film & Animation         1.183527e+10
# Gaming                   7.634456e+09
# Howto & Style            5.045439e+09
# Movies                   7.691628e+09
# Music                    1.545286e+10
# News & Politics          1.039969e+10
# Nonprofits & Activism    5.431456e+09
# People & Blogs           9.589327e+09
# Pets & Animals           1.121669e+10
# Science & Technology     3.939809e+09
# Shows                    3.432360e+10
# Sports                   1.345330e+10
# Trailers                 1.663136e+10
# Travel & Events          3.140883e+09
# Name: video views, dtype: float64

# %% [markdown]
# #Data visualization

# %%
#Number of channels by each country
country_counts = df["Country"].value_counts()

plt.figure(figsize=(10,6))

sns.barplot(
    x=country_counts.head(10).values,
    y=country_counts.head(10).index,
    palette="viridis"
)

plt.title("Top Countries by YouTube Channels")
plt.xlabel("Number of Channels")
plt.ylabel("Country")
plt.show()
# Out:
# /tmp/ipykernel_267/2433900291.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
#Top youtube categories
df["category"].value_counts().head(10).plot(
    kind="bar",
    colormap="viridis"
)

plt.title("Top YouTube Categories")
plt.show()

# %%
#Number of uploded videos vs the number of subscribers of the channel
sns.scatterplot(x="uploads", y="subscribers", data=df)
plt.title("Uploads vs Subscribers")
plt.show()

# %%
#Coorelation Heatmap
corr = df.corr(numeric_only=True)
plt.figure(figsize=(16,12))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# #Phase 5 — Trend Analysis

# %%
#Channels created per year
df["created_year"].value_counts().sort_index().plot(kind="line")
plt.title("Channels Created Per Year")
plt.show()

# %% [markdown]
# #Key Insights

# %% [markdown]
# * Music and entertainment channels have the highest subscribers.
#
# * Channels from the USA and India dominate YouTube rankings.
#
# * Entertainment channels generate higher video views.
#
# * Some channels generate extremely high views despite fewer uploads.
